# %%
from LLM_judge import LLMJudge

# %%
judge = LLMJudge()

# %%
batch_data = [
    {"question": "What's next to the bed?", "ground_truth": "2 night tables", "candidate_answer": "two side tables"},
    {"question": "Which item is in front of the sofa?", "ground_truth": "A coffee table", "candidate_answer": "A wooden coffee table"},
    {"question": "What's under the dining table?", "ground_truth": "A rug", "candidate_answer": "A carpet"},
    {"question": "What's on top of the desk?", "ground_truth": "A lamp", "candidate_answer": "A desk lamp"},
    {"question": "What's behind the TV?", "ground_truth": "A wall", "candidate_answer": "A painted wall"},
    {"question": "What's next to the refrigerator?", "ground_truth": "A pantry", "candidate_answer": "A storage cabinet"},
    {"question": "What's above the bed?", "ground_truth": "A painting", "candidate_answer": "A framed picture"},
    {"question": "What's beside the bathtub?", "ground_truth": "A towel rack", "candidate_answer": "A towel holder"},
    {"question": "What's in front of the armchair?", "ground_truth": "A footstool", "candidate_answer": "An ottoman"},
    {"question": "What's next to the wardrobe?", "ground_truth": "A mirror", "candidate_answer": "A full-length mirror"},
    {"question": "What's the width of the bed?", "ground_truth": "1.5 meters", "candidate_answer": "145 cm"},
    # Incorrect matches
    {"question": "What's next to the bed?", "ground_truth": "2 night tables", "candidate_answer": "A wardrobe"},
    {"question": "Which item is in front of the sofa?", "ground_truth": "A coffee table", "candidate_answer": "A TV stand"},
    {"question": "What's under the dining table?", "ground_truth": "A rug", "candidate_answer": "A chair"},
    {"question": "What's on top of the desk?", "ground_truth": "A lamp", "candidate_answer": "A book"},
    {"question": "What's behind the TV?", "ground_truth": "A wall", "candidate_answer": "A window"},
    {"question": "What's the width of the bed?", "ground_truth": "1.5 meters", "candidate_answer": "90 cm"},
]

results = judge.process_batch(batch_data)
print(results)
