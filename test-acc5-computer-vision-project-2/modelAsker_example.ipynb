# %%
import pandas as pd

df = pd.read_csv("gemini_results_sequential_final.csv")
df = df[["path", "description", "question"]]
df = df.to_dict(orient="records")

print(df)

# %%
from model_asker import ModelAsker

asker = ModelAsker()

asker.process_batch(df)
